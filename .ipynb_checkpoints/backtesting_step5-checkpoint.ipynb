# %%
### 해당 코드는 백테스팅을 하는 코드입니다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 포트폴리오 비중 데이터프레임을 불러옵니다.
last_weight_pd=pd.read_excel('last_portfolio_weight.xlsx',index_col=0)

# %%
#달러의 경우 비중을 따로 저장해둡니다. 매트릭스 형태 곱에서 제외해서 나중에 더해줄 예정입니다. 이유는 모든 자산이 달러로 사야하기 때문입니다.
dollar_weight=last_weight_pd.dollar.asfreq('B').ffill()

# %%
# ETF 변화율 데이터를 가져옵니다.
ETF_pd=pd.read_excel('all_ETF_data.xlsx',index_col=0)

# %%
ETF_pd
# Out:
#                 gold      GOVT       GSY       HSV       HYG       IEF  \
# Date
# 2010-12-06  0.006838  0.004114  0.000000  0.000084 -0.000581  0.006257
# 2010-12-07 -0.015220 -0.010471 -0.000804  0.000000  0.005170 -0.016580
# 2010-12-08 -0.014300 -0.003451  0.000000  0.000000 -0.003230 -0.008535
# 2010-12-09  0.003676 -0.000115  0.000000  0.000000 -0.002121  0.002125
# 2010-12-10 -0.000707 -0.002193  0.000604  0.000000  0.000448 -0.008485
# ...              ...       ...       ...       ...       ...       ...
# 2023-01-09  0.003280  0.002483  0.001010  0.000078  0.003575  0.002541
# 2023-01-10  0.002789 -0.004573  0.000000  0.000000 -0.001187 -0.006286
# 2023-01-11 -0.000714  0.004786  0.000202  0.000156  0.006604  0.006428
# 2023-01-12  0.011409  0.006954  0.001008  0.000312  0.005642  0.008921
# 2023-01-13  0.012198 -0.003595  0.000403  0.000312  0.000000 -0.005326
#
#                  LQD      LTPZ       SHV       SHY      SHYG      TIPS  \
# Date
# 2010-12-06  0.006979  0.009781  0.000091  0.001141  0.000835  0.005365
# 2010-12-07 -0.009302 -0.015784  0.000000 -0.002239  0.001848 -0.011376
# 2010-12-08 -0.006444 -0.017311  0.000000 -0.001142 -0.000897 -0.007735
# 2010-12-09  0.002410 -0.001487  0.000000 -0.000286  0.000730 -0.001792
# 2010-12-10 -0.004622 -0.005572 -0.000181 -0.000082  0.000125 -0.002291
# ...              ...       ...       ...       ...       ...       ...
# 2023-01-09  0.003959  0.008526  0.000091  0.001083  0.004319  0.002728
# 2023-01-10 -0.003394 -0.013331 -0.000091 -0.000597 -0.001011 -0.004209
# 2023-01-11  0.008559  0.012193  0.000273  0.000635  0.003135  0.004828
# 2023-01-12  0.011315  0.015465  0.000545  0.001790  0.003333  0.006983
# 2023-01-13 -0.003248 -0.021642  0.000000  0.000000  0.000011  0.000000
#
#                  TLT      VCIT      VCLT      VCSH      VTIP
# Date
# 2010-12-06  0.010866  0.003125  0.009454  0.002317  0.002403
# 2010-12-07 -0.027978 -0.008478 -0.014625 -0.004197 -0.001698
# 2010-12-08 -0.003636 -0.008613 -0.001979 -0.002358 -0.003400
# 2010-12-09  0.006994  0.001333  0.003940 -0.001421 -0.000202
# 2010-12-10 -0.003775 -0.004435 -0.002287 -0.002069 -0.000903
# ...              ...       ...       ...       ...       ...
# 2023-01-09  0.005389  0.003787  0.004409  0.001189  0.000926
# 2023-01-10 -0.015983 -0.002012 -0.005769 -0.000528 -0.000617
# 2023-01-11  0.015945  0.005671  0.013496  0.001980  0.000823
# 2023-01-12  0.019302  0.008772  0.015930  0.003556  0.003907
# 2023-01-13 -0.008894 -0.003478 -0.003553 -0.001575 -0.001946
#
# [3196 rows x 17 columns]

# %%
#기타 다른 데이터를 가져옵니다.

other_data=pd.read_excel('Data-FICC_Modeling.xlsx',index_col=0,sheet_name='ETC').iloc[1:,4:]

# %% [markdown]
# #### 기준금리와 환율은 따로 생각해주기위해 데이터프레임형태로 각각 저장해둡니다.

# %%
risk_free=other_data.loc[last_weight_pd.index,'한국 기준금리']+0.001 #기준금리 +가산금리
risk_free=(risk_free*5/(100*252)).loc[last_weight_pd.index].asfreq('B').fillna(0)
risk_free=risk_free.iloc[1:-1] # 필요없는 날짜 제거

exchange_pd=other_data.loc[:,'원달러 환율']
exchange_pd=exchange_pd.asfreq('B').pct_change().dropna() #변화율로 변경

# %% [markdown]
# #### 비중 값을 비지니스 데이로 바꿔준 뒤 필요없는 처음날짜와 끝날짜를 제거해줍니다.

# %%
last_weight_pd=last_weight_pd.asfreq('D').asfreq('B').ffill().iloc[1:-1]

# %%
last_weight_pd
# Out:
#               dollar       HYG      SHYG       LQD      VCLT      VCIT  \
# 2014-01-02  0.060236  0.061817  0.188183  0.012441  0.007687  0.014131
# 2014-01-03  0.060236  0.061817  0.188183  0.012441  0.007687  0.014131
# 2014-01-06  0.060236  0.061817  0.188183  0.012441  0.007687  0.014131
# 2014-01-07  0.060236  0.061817  0.188183  0.012441  0.007687  0.014131
# 2014-01-08  0.060236  0.061817  0.188183  0.012441  0.007687  0.014131
# ...              ...       ...       ...       ...       ...       ...
# 2022-11-24  0.500000  0.008120  0.016880  0.001668  0.001153  0.002347
# 2022-11-25  0.500000  0.008120  0.016880  0.001668  0.001153  0.002347
# 2022-11-28  0.500000  0.008120  0.016880  0.001668  0.001153  0.002347
# 2022-11-29  0.500000  0.008120  0.016880  0.001668  0.001153  0.002347
# 2022-11-30  0.500000  0.008120  0.016880  0.001668  0.001153  0.002347
#
#                 VCSH       GSY      LTPZ      VTIP      GOVT       TLT  \
# 2014-01-02  0.042409  0.173331  0.042976  0.282877  0.000943  0.000258
# 2014-01-03  0.042409  0.173331  0.042976  0.282877  0.000943  0.000258
# 2014-01-06  0.042409  0.173331  0.042976  0.282877  0.000943  0.000258
# 2014-01-07  0.042409  0.173331  0.042976  0.282877  0.000943  0.000258
# 2014-01-08  0.042409  0.173331  0.042976  0.282877  0.000943  0.000258
# ...              ...       ...       ...       ...       ...       ...
# 2022-11-24  0.004466  0.015366  0.009744  0.063212  0.001259  0.000410
# 2022-11-25  0.004466  0.015366  0.009744  0.063212  0.001259  0.000410
# 2022-11-28  0.004466  0.015366  0.009744  0.063212  0.001259  0.000410
# 2022-11-29  0.004466  0.015366  0.009744  0.063212  0.001259  0.000410
# 2022-11-30  0.004466  0.015366  0.009744  0.063212  0.001259  0.000410
#
#                  IEF       SHY       SHV      gold
# 2014-01-02  0.000579  0.006819  0.041402  0.063911
# 2014-01-03  0.000579  0.006819  0.041402  0.063911
# 2014-01-06  0.000579  0.006819  0.041402  0.063911
# 2014-01-07  0.000579  0.006819  0.041402  0.063911
# 2014-01-08  0.000579  0.006819  0.041402  0.063911
# ...              ...       ...       ...       ...
# 2022-11-24  0.000892  0.005987  0.041452  0.327044
# 2022-11-25  0.000892  0.005987  0.041452  0.327044
# 2022-11-28  0.000892  0.005987  0.041452  0.327044
# 2022-11-29  0.000892  0.005987  0.041452  0.327044
# 2022-11-30  0.000892  0.005987  0.041452  0.327044
#
# [2325 rows x 16 columns]

# %% [markdown]
# ####  달러 칼럼을 제거해줍니다. 나중에 따로 더해줄 예정입니다.

# %%
tmt_col=list(last_weight_pd.columns)
tmt_col.remove('dollar')

# %%
adjust_ETF_pd=ETF_pd.loc[:,tmt_col].loc['2014-01':'2022-11'].iloc[1:].asfreq('D').asfreq('B')

# %% [markdown]
# #### 데이터의 행개수가 같은지, 혹은 날짜가 전부 같은지 확인합니다.

# %%
np.shape(adjust_ETF_pd),np.shape(last_weight_pd)
# Out:
# ((2325, 15), (2325, 16))

# %%
#달러 weight 제거
adjust_last_weight_pd=last_weight_pd.iloc[:,1:]

# %%
adjust_last_weight_pd
# Out:
#                  HYG      SHYG       LQD      VCLT      VCIT      VCSH  \
# 2014-01-02  0.061817  0.188183  0.012441  0.007687  0.014131  0.042409
# 2014-01-03  0.061817  0.188183  0.012441  0.007687  0.014131  0.042409
# 2014-01-06  0.061817  0.188183  0.012441  0.007687  0.014131  0.042409
# 2014-01-07  0.061817  0.188183  0.012441  0.007687  0.014131  0.042409
# 2014-01-08  0.061817  0.188183  0.012441  0.007687  0.014131  0.042409
# ...              ...       ...       ...       ...       ...       ...
# 2022-11-24  0.008120  0.016880  0.001668  0.001153  0.002347  0.004466
# 2022-11-25  0.008120  0.016880  0.001668  0.001153  0.002347  0.004466
# 2022-11-28  0.008120  0.016880  0.001668  0.001153  0.002347  0.004466
# 2022-11-29  0.008120  0.016880  0.001668  0.001153  0.002347  0.004466
# 2022-11-30  0.008120  0.016880  0.001668  0.001153  0.002347  0.004466
#
#                  GSY      LTPZ      VTIP      GOVT       TLT       IEF  \
# 2014-01-02  0.173331  0.042976  0.282877  0.000943  0.000258  0.000579
# 2014-01-03  0.173331  0.042976  0.282877  0.000943  0.000258  0.000579
# 2014-01-06  0.173331  0.042976  0.282877  0.000943  0.000258  0.000579
# 2014-01-07  0.173331  0.042976  0.282877  0.000943  0.000258  0.000579
# 2014-01-08  0.173331  0.042976  0.282877  0.000943  0.000258  0.000579
# ...              ...       ...       ...       ...       ...       ...
# 2022-11-24  0.015366  0.009744  0.063212  0.001259  0.000410  0.000892
# 2022-11-25  0.015366  0.009744  0.063212  0.001259  0.000410  0.000892
# 2022-11-28  0.015366  0.009744  0.063212  0.001259  0.000410  0.000892
# 2022-11-29  0.015366  0.009744  0.063212  0.001259  0.000410  0.000892
# 2022-11-30  0.015366  0.009744  0.063212  0.001259  0.000410  0.000892
#
#                  SHY       SHV      gold
# 2014-01-02  0.006819  0.041402  0.063911
# 2014-01-03  0.006819  0.041402  0.063911
# 2014-01-06  0.006819  0.041402  0.063911
# 2014-01-07  0.006819  0.041402  0.063911
# 2014-01-08  0.006819  0.041402  0.063911
# ...              ...       ...       ...
# 2022-11-24  0.005987  0.041452  0.327044
# 2022-11-25  0.005987  0.041452  0.327044
# 2022-11-28  0.005987  0.041452  0.327044
# 2022-11-29  0.005987  0.041452  0.327044
# 2022-11-30  0.005987  0.041452  0.327044
#
# [2325 rows x 15 columns]

# %% [markdown]
# #### 모델의 일일 성과 데이터프레임을 만들어줍니다.

# %%
simulation_pd=(adjust_ETF_pd*adjust_last_weight_pd).sum(axis=1)

# 달러 환전 고려

simulation_pd=simulation_pd+ (1+dollar_weight)*exchange_pd.asfreq('B').loc[:"2022-11"]
# 무위험 이자율(금리) 제거
simulation_pd=simulation_pd-risk_free

# %%
model_backtest_pd=((simulation_pd+1).cumprod()-1)

# %%
# NA 값 제거해줍니다.

model_backtest_pd=model_backtest_pd.dropna()

# %%
model_backtest_pd.plot()
# Out:
# <AxesSubplot:>

# %%
#원달러 환율 날짜 맞추는 과정
exchange_rate=pd.DataFrame(exchange_pd.asfreq('B').loc[:"2022-11"].reset_index(drop=True).T)
exchange_rate.index=adjust_ETF_pd.index
exchange_rate
# Out:
#               원달러 환율
# Date
# 2014-01-02 -0.005304
# 2014-01-03  0.004742
# 2014-01-06  0.009657
# 2014-01-07  0.002778
# 2014-01-08 -0.003594
# ...              ...
# 2022-11-24 -0.017579
# 2022-11-25 -0.002973
# 2022-11-28  0.012276
# 2022-11-29 -0.010211
# 2022-11-30 -0.006541
#
# [2325 rows x 1 columns]

# %% [markdown]
# ### 다음은 벤치마크인 동일비중 투자 방식을 구현한 코드입니다.

# %%
benchmark=(pd.DataFrame(np.array(adjust_ETF_pd.mean(axis=1))).T 
           
benchmark= benchmark + np.array(exchange_rate).T).T

# %%
benchmark.index=adjust_ETF_pd.index
benchmark.columns=['benchmark']

# %% [markdown]
# #### 무위험 이자율을 뺴줍니다.

# %%
benchmark_pd=np.array(benchmark).T- np.array(risk_free).T

# %% [markdown]
# #### 벤치마크의 누적수익률을 구합니다.

# %%
benchmark_backtest_pd=pd.DataFrame((benchmark_pd+1).T).cumprod()-1

# %%
benchmark_simulation=pd.DataFrame(benchmark_backtest_pd)
benchmark_simulation.columns=['benchmark']
benchmark_simulation.index=model_backtest_pd.index

# %%
benchmark_simulation
# Out:
#             benchmark
# 2014-01-02  -0.002628
# 2014-01-03   0.003150
# 2014-01-06   0.014650
# 2014-01-07   0.018054
# 2014-01-08   0.012392
# ...               ...
# 2022-11-24   0.532987
# 2022-11-25   0.528446
# 2022-11-28   0.542217
# 2022-11-29   0.522132
# 2022-11-30   0.525766
#
# [2325 rows x 1 columns]

# %%
plt.figure(figsize=(20,10))
plt.plot(benchmark_simulation,label='benchmark')
plt.plot(model_backtest_pd,label='model')
plt.title('backtesting simulation',fontsize=25)
plt.legend()
