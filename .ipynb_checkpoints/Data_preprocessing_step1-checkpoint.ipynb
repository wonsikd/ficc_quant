# %%
import pandas as pd
import os

# %% [markdown]
# ## 해당 코드는 데이터를 전처리한 과정을 보여주는 과정입니다.
# ## 블룸버그에서 가져온 데이터를 모두 정리해서 국면에 넣어줄 형태를 만들어주는 코드입니다.
# ## 가장 먼저 시행해야하는 코드입니다.

# %%
path = 'C:/Users/User/ficc_quant/data'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.xlsx')]

# %% [markdown]
# #### 데이터 파일 목록은 다음과 같습니다.

# %%
file_list_py
# Out:
# ['Chicago FED Adjusted.xlsx',
#  'corporate_bond.xlsx',
#  'dollar.xlsx',
#  'gold.xlsx',
#  'gover_3month.xlsx',
#  'highyield_spread(CSI BARC Index).xlsx',
#  'high_yield_real.xlsx',
#  'Investment Grade.xlsx',
#  'TED Spread.xlsx',
#  'TIPS.xlsx',
#  'US treasury_bond.xlsx',
#  'vix.xlsx']

# %% [markdown]
# ### 데이터를 모두 붙혀줍니다.

# %%
file_list_py
name_list=[]
for index,file in enumerate(file_list_py):
    
    file_data=pd.read_excel(path+'/'+file)
    name=file_data.iloc[0].index[1]
    file_data=pd.DataFrame(file_data.iloc[5:,:2]).reset_index(drop=True).iloc[::-1]
    file_data.columns=['Date',name]
    
    file_data.loc[:,name]=file_data.loc[:,name]
    file_data=file_data.reset_index(drop=True)
    #break
    #print(file_data.iloc[0].index[1])
    name_list.append(name)
    print(name,index)
    if index>0:
        all_file_data=pd.merge(all_file_data,file_data, how='outer')
    else:
        all_file_data=file_data
    #print(file_data)
# Out:
# NFCIADJ  Index                                                   0
# LUACTRUU Index                                                   1
# DXY Curncy                                                       2
# XAU BGN Curncy                                                   3
# USGG3M   Index                                                   4
# CSI BARC Index                                                   5
# I14031US Index                                                   6
# LUACOAS  Index                                                   7
# US0003M  Index                                                   8
# TIPS 9
# LUATTRUU Index                                                   10
# VIX Index                                                        11

# %%
all_file_data.Date=pd.to_datetime(all_file_data.Date,errors='coerce')#.to_excel('버그.xlsx')
all_file_data=all_file_data.loc[all_file_data.Date != None].reset_index(drop=True)#.iloc[:-2,:]
all_file_data=all_file_data.sort_values(by=['Date'])#.iloc[:-1,:]#.to_excel('all_data.xlsx')
all_file_data=all_file_data.ffill()
index_data=all_file_data#.dropna()

# %% [markdown]
# ### 데이터를 모두 붙혀주면 다음과 같이null 값이 많습니다. 이를 전처리해줍니다.

# %%
index_data
# Out:
#            Date  \
# 0    1973-01-31
# 1    1973-02-28
# 2    1973-03-30
# 3    1973-04-30
# 4    1973-05-31
# ...         ...
# 8813 2023-01-10
# 8814 2023-01-11
# 8815 2023-01-12
# 8816 2023-01-13
# 8817 2023-01-13
#
#       NFCIADJ  Index                                                    \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8813                                           -0.25595
# 8814                                           -0.25595
# 8815                                           -0.25595
# 8816                                           -0.25595
# 8817                                           -0.25595
#
#       LUACTRUU Index                                                    \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8813                                            3028.97
# 8814                                            3052.29
# 8815                                            3079.12
# 8816                                            3069.92
# 8817                                            3069.92
#
#      DXY Curncy                                                        \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8813                                            103.236
# 8814                                            103.188
# 8815                                            102.246
# 8816                                            102.204
# 8817                                            PX_LAST
#
#      XAU BGN Curncy                                                    \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8813                                            1877.03
# 8814                                            1875.69
# 8815                                            1897.09
# 8816                                            1920.23
# 8817                                            PX_LAST
#
#       USGG3M   Index                                                    \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8813                                             4.5845
# 8814                                             4.6565
# 8815                                             4.5755
# 8816                                             4.5732
# 8817                                             4.5732
#
#       CSI BARC Index                                                    \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8813                                               4.73
# 8814                                               4.71
# 8815                                               4.65
# 8816                                               4.65
# 8817                                               4.65
#
#       I14031US Index                                                    \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8813                                           399.2509
# 8814                                           401.0719
# 8815                                           402.3142
# 8816                                           404.4192
# 8817                                           404.4192
#
#       LUACOAS  Index                                                    \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8813                                               1.28
# 8814                                               1.26
# 8815                                               1.25
# 8816                                               1.24
# 8817                                               1.24
#
#       US0003M  Index                                                    \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8813                                            4.80586
# 8814                                            4.81500
# 8815                                            4.82971
# 8816                                            4.82971
# 8817                                            4.82971
#
#           TIPS  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 8813  329.7089
# 8814  329.7089
# 8815  329.7089
# 8816  329.7089
# 8817  329.7089
#
#       LUATTRUU Index                                                    \
# 0                                                 98.99
# 1                                                 98.73
# 2                                                 98.73
# 3                                                 99.66
# 4                                                 99.88
# ...                                                 ...
# 8813                                            2220.21
# 8814                                            2230.83
# 8815                                            2246.33
# 8816                                            2238.14
# 8817                                            2238.14
#
#       VIX Index
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8813                                              20.58
# 8814                                              21.09
# 8815                                              18.83
# 8816                                              18.35
# 8817                                              18.35
#
# [8818 rows x 13 columns]

# %%
index_data=index_data.dropna().iloc[:-5].drop_duplicates('Date').set_index('Date').asfreq('w-fri').loc['2000-12':]

# %% [markdown]
# ### Ted spread를 만들어줍니다.

# %%
index_data.columns=['condition'	,'corporate','dollar','gold','short_corporate','spread','highyield','investment_grade','Libor','TIPS','US_bond','VIX Index']                                                       
index_data.condition=index_data.condition+1
index_data.loc[:,'Ted_spread']=index_data.loc[:,'short_corporate']-index_data.Libor

# %% [markdown]
# ### 미리 인덱스 값을 저장해줍니다.

# %%
date_col=index_data.index

# %% [markdown]
# ### 가격의변동률을 저장해줍니다. 이후 백테스팅이나 비중 최적화에 쓰일 데이터입니다.

# %%
index_data.pct_change().iloc[1:].loc[:,['condition'	,'corporate','dollar','gold','short_corporate','spread','highyield','investment_grade','Libor','TIPS','US_bond','VIX Index','Ted_spread']   ].to_excel('price_change.xlsx')

# %% [markdown]
# ### 다음은 국면을 판별할때 필요한 데이터를 모아놓은 데이터를 저장해줍니다.(all_index_data.xlsx)
# ### 차분을 해줘야합니다.

# %%
index_data.columns=['condition'	,'corporate','dollar','gold','highyield','spread','investment_grade','Libor','TIPS','US_bond','VIX Index','short_corporate','Ted_spread']
index_data.index=date_col
index_data=index_data.diff().iloc[1:]

# %%
index_data
# Out:
#             condition  corporate dollar   gold  highyield  spread  \
# Date
# 2000-12-08   0.034703      10.75  -0.68    3.4    -0.1590    0.44
# 2000-12-15   0.024545       9.91  -1.15  -1.85    -0.0210   -0.29
# 2000-12-22   0.009130       6.03  -2.08    3.0    -0.7760    0.09
# 2000-12-29  -0.015408      -3.64  -1.26   -1.7     0.6340   -0.04
# 2001-01-05  -0.030062      19.42  -1.14   -4.1    -0.7790   -0.05
# ...               ...        ...    ...    ...        ...     ...
# 2022-12-09  -0.018182      -7.93  0.265  -0.31     0.0155    0.05
# 2022-12-16  -0.025095      16.48 -0.109  -4.24    -0.0129    0.14
# 2022-12-23  -0.029912     -50.09 -0.387   5.12     0.0331   -0.14
# 2022-12-30  -0.026281     -21.37 -0.792  25.82     0.0595    0.15
# 2023-01-06  -0.016971      59.23  0.357  41.67     0.2361   -0.22
#
#             investment_grade  Libor     TIPS  US_bond  VIX Index  \
# Date
# 2000-12-08            0.0000  -0.07 -0.11625   0.4602       9.33
# 2000-12-15            0.0000   0.00 -0.02062   0.3377       9.70
# 2000-12-22            0.0000   0.06 -0.09938   0.7135       8.70
# 2000-12-29            1.2969   0.01 -0.05125  -0.0796      -4.21
# 2001-01-05            0.0000  -0.07 -0.70375   2.1885      12.22
# ...                      ...    ...      ...      ...        ...
# 2022-12-09            3.3529   0.00  0.00057  -5.1649      -9.19
# 2022-12-16            1.0165   0.02  0.01272  -1.4716      15.02
# 2022-12-23           -4.3768  -0.02 -0.01943  -2.4330     -31.41
# 2022-12-30           -3.4559   0.00  0.04086  -0.4724     -12.31
# 2023-01-06            6.2912   0.02  0.04257   3.5429      36.58
#
#             short_corporate  Ted_spread
# Date
# 2000-12-08            -5.07    -0.04275
# 2000-12-15             4.14    -0.00038
# 2000-12-22             1.00    -0.67662
# 2000-12-29            -0.70     0.68525
# 2001-01-05             1.82    -0.07525
# ...                     ...         ...
# 2022-12-09             3.77     0.01493
# 2022-12-16            -0.21    -0.02562
# 2022-12-23            -1.75     0.05253
# 2022-12-30             0.80     0.01864
# 2023-01-06            -0.54     0.19353
#
# [1153 rows x 13 columns]

# %%
index_data.to_excel('all_index_data.xlsx')
