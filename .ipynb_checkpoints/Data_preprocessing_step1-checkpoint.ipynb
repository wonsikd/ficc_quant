# %%
import pandas as pd
import os

# %% [markdown]
# ## 해당 코드는 데이터를 전처리한 과정을 보여주는 과정입니다.
# ## 블룸버그에서 가져온 데이터를 모두 정리해서 국면에 넣어줄 형태를 만들어주는 코드입니다.
# ## 가장 먼저 시행해야하는 코드입니다.

# %%
path = 'C:/Users/User/ficc_quant/data'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.xlsx')]

# %% [markdown]
# #### 데이터 파일 목록은 다음과 같습니다.

# %%
file_list_py
# Out:
# ['Chicago FED Adjusted.xlsx',
#  'corporate_bond.xlsx',
#  'dollar.xlsx',
#  'gold.xlsx',
#  'gover_3month.xlsx',
#  'highyield_spread(CSI BARC Index).xlsx',
#  'high_yield_real.xlsx',
#  'Investment Grade.xlsx',
#  'TED Spread.xlsx',
#  'TIPS.xlsx',
#  'US treasury_bond.xlsx',
#  'vix.xlsx']

# %% [markdown]
# ### 데이터를 모두 붙혀줍니다.

# %%
file_list_py
name_list=[]
for index,file in enumerate(file_list_py):
    
    file_data=pd.read_excel(path+'/'+file)
    name=file_data.iloc[0].index[1]
    file_data=pd.DataFrame(file_data.iloc[5:,:2]).reset_index(drop=True).iloc[::-1]
    file_data.columns=['Date',name]
    
    file_data.loc[:,name]=file_data.loc[:,name]
    file_data=file_data.reset_index(drop=True)
    #break
    #print(file_data.iloc[0].index[1])
    name_list.append(name)
    print(name,index)
    if index>0:
        all_file_data=pd.merge(all_file_data,file_data, how='outer')
    else:
        all_file_data=file_data
    #print(file_data)
# Out:
# NFCIADJ  Index                                                   0
# LUACTRUU Index                                                   1
# DXY Curncy                                                       2
# XAU BGN Curncy                                                   3
# USGG3M   Index                                                   4
# CSI BARC Index                                                   5
# I14031US Index                                                   6
# LUACOAS  Index                                                   7
# US0003M  Index                                                   8
# TIPS 9
# LUATTRUU Index                                                   10
# VIX Index                                                        11

# %%
all_file_data.Date=pd.to_datetime(all_file_data.Date,errors='coerce')#.to_excel('버그.xlsx')
all_file_data=all_file_data.loc[all_file_data.Date != None].reset_index(drop=True)#.iloc[:-2,:]
all_file_data=all_file_data.sort_values(by=['Date'])#.iloc[:-1,:]#.to_excel('all_data.xlsx')
all_file_data=all_file_data.ffill()
index_data=all_file_data#.dropna()

# %% [markdown]
# ### 데이터를 모두 붙혀주면 다음과 같이null 값이 많습니다. 이를 전처리해줍니다.

# %%
index_data
# Out:
#            Date  \
# 8612 1973-01-31
# 8613 1973-02-28
# 8614 1973-03-30
# 8615 1973-04-30
# 8616 1973-05-31
# ...         ...
# 6303 2023-01-10
# 6304 2023-01-11
# 6305 2023-01-12
# 6306 2023-01-13
# 6506 2023-01-13
#
#       NFCIADJ  Index                                                    \
# 8612                                                NaN
# 8613                                                NaN
# 8614                                                NaN
# 8615                                                NaN
# 8616                                                NaN
# ...                                                 ...
# 6303                                           -0.25595
# 6304                                           -0.25595
# 6305                                           -0.25595
# 6306                                           -0.25595
# 6506                                           -0.25595
#
#       LUACTRUU Index                                                    \
# 8612                                                NaN
# 8613                                                NaN
# 8614                                                NaN
# 8615                                                NaN
# 8616                                                NaN
# ...                                                 ...
# 6303                                            3028.97
# 6304                                            3052.29
# 6305                                            3079.12
# 6306                                            3069.92
# 6506                                            3069.92
#
#      DXY Curncy                                                        \
# 8612                                                NaN
# 8613                                                NaN
# 8614                                                NaN
# 8615                                                NaN
# 8616                                                NaN
# ...                                                 ...
# 6303                                            103.236
# 6304                                            103.188
# 6305                                            102.246
# 6306                                            102.204
# 6506                                            PX_LAST
#
#      XAU BGN Curncy                                                    \
# 8612                                                NaN
# 8613                                                NaN
# 8614                                                NaN
# 8615                                                NaN
# 8616                                                NaN
# ...                                                 ...
# 6303                                            1877.03
# 6304                                            1875.69
# 6305                                            1897.09
# 6306                                            1920.23
# 6506                                            PX_LAST
#
#       USGG3M   Index                                                    \
# 8612                                                NaN
# 8613                                                NaN
# 8614                                                NaN
# 8615                                                NaN
# 8616                                                NaN
# ...                                                 ...
# 6303                                             4.5845
# 6304                                             4.6565
# 6305                                             4.5755
# 6306                                             4.5732
# 6506                                             4.5732
#
#       CSI BARC Index                                                    \
# 8612                                                NaN
# 8613                                                NaN
# 8614                                                NaN
# 8615                                                NaN
# 8616                                                NaN
# ...                                                 ...
# 6303                                               4.73
# 6304                                               4.71
# 6305                                               4.65
# 6306                                               4.65
# 6506                                               4.65
#
#       I14031US Index                                                    \
# 8612                                                NaN
# 8613                                                NaN
# 8614                                                NaN
# 8615                                                NaN
# 8616                                                NaN
# ...                                                 ...
# 6303                                           399.2509
# 6304                                           401.0719
# 6305                                           402.3142
# 6306                                           404.4192
# 6506                                           404.4192
#
#       LUACOAS  Index                                                    \
# 8612                                                NaN
# 8613                                                NaN
# 8614                                                NaN
# 8615                                                NaN
# 8616                                                NaN
# ...                                                 ...
# 6303                                               1.28
# 6304                                               1.26
# 6305                                               1.25
# 6306                                               1.24
# 6506                                               1.24
#
#       US0003M  Index                                                    \
# 8612                                                NaN
# 8613                                                NaN
# 8614                                                NaN
# 8615                                                NaN
# 8616                                                NaN
# ...                                                 ...
# 6303                                            4.80586
# 6304                                            4.81500
# 6305                                            4.82971
# 6306                                            4.82971
# 6506                                            4.82971
#
#           TIPS  \
# 8612       NaN
# 8613       NaN
# 8614       NaN
# 8615       NaN
# 8616       NaN
# ...        ...
# 6303  329.7089
# 6304  329.7089
# 6305  329.7089
# 6306  329.7089
# 6506  329.7089
#
#       LUATTRUU Index                                                    \
# 8612                                              98.99
# 8613                                              98.73
# 8614                                              98.73
# 8615                                              99.66
# 8616                                              99.88
# ...                                                 ...
# 6303                                            2220.21
# 6304                                            2230.83
# 6305                                            2246.33
# 6306                                            2238.14
# 6506                                            2238.14
#
#       VIX Index
# 8612                                                NaN
# 8613                                                NaN
# 8614                                                NaN
# 8615                                                NaN
# 8616                                                NaN
# ...                                                 ...
# 6303                                              20.58
# 6304                                              21.09
# 6305                                              18.83
# 6306                                              18.35
# 6506                                              18.35
#
# [8818 rows x 13 columns]

# %%
index_data=index_data.dropna().iloc[:-5].drop_duplicates('Date').set_index('Date').asfreq('w-fri').loc['2000-12':]

# %% [markdown]
# ### Ted spread를 만들어줍니다.

# %%
index_data.columns=['condition'	,'corporate','dollar','gold','short_corporate','spread','highyield','investment_grade','Libor','TIPS','US_bond','VIX Index']                                                       
index_data.condition=index_data.condition+1
index_data.loc[:,'Ted_spread']=index_data.loc[:,'short_corporate']-index_data.Libor

# %% [markdown]
# ### 미리 인덱스 값을 저장해줍니다.

# %%
date_col=index_data.index

# %% [markdown]
# ### 가격의변동률을 저장해줍니다. 이후 백테스팅이나 비중 최적화에 쓰일 데이터입니다.

# %%
index_data.pct_change().iloc[1:].loc[:,['condition'	,'corporate','dollar','gold','short_corporate','spread','highyield','investment_grade','Libor','TIPS','US_bond','VIX Index','Ted_spread']   ].to_excel('price_change.xlsx')

# %% [markdown]
# ### 다음은 국면을 판별할때 필요한 데이터를 모아놓은 데이터를 저장해줍니다.(all_index_data.xlsx)
# ### 차분을 해줘야합니다.

# %%
index_data.columns=['condition'	,'corporate','dollar','gold','highyield','spread','investment_grade','Libor','TIPS','US_bond','VIX Index','short_corporate','Ted_spread']
index_data.index=date_col

# %%
index_data=index_data.fillna(1).diff().iloc[1:].ffill()
index_data
# Out:
#             condition  corporate    dollar      gold  highyield    spread  \
# Date
# 2000-12-29  -0.002213  -0.002545  0.020069 -0.071807   0.473747 -0.157348
# 2001-01-05   0.009609   0.034791 -0.021924  0.043068  -0.769151  0.060440
# 2001-01-12  -0.001903  -0.077315  0.023190  0.001546   0.841034 -0.094764
# 2001-01-19  -0.002947   0.093813 -0.030135  0.005580  -0.592777  0.229291
# 2001-01-26   0.006785  -0.073473  0.002803 -0.039595   0.244048 -0.240520
# ...               ...        ...       ...       ...        ...       ...
# 2022-12-09  -0.001112  -0.021591  0.009331 -0.052343   0.012188  0.016664
# 2022-12-16   0.004097   0.049730 -0.039424  0.067316  -0.024082 -0.012362
# 2022-12-23   0.002480  -0.058205  0.020214 -0.014623   0.024906 -0.061636
# 2022-12-30   0.003724   0.062356 -0.002158 -0.001345  -0.017925  0.157024
# 2023-01-06  -0.001372  -0.015030  0.016095 -0.009139   0.029684 -0.206011
#
#             investment_grade     Libor      TIPS   US_bond  VIX Index  \
# Date
# 2000-12-29          0.008868 -0.033113  0.040270 -0.013556  -0.009659
# 2001-01-05         -0.026682  0.026103 -0.127011  0.033964   0.037658
# 2001-01-12          0.026761  0.041455  0.311430 -0.064416  -0.066788
# 2001-01-19         -0.008947 -0.037799 -0.307203  0.069709   0.085202
# 2001-01-26          0.000000  0.014338  0.117074 -0.041832  -0.075377
# ...                      ...       ...       ...       ...        ...
# 2022-12-09         -0.049984 -0.014093  0.026661 -0.042294  -0.025018
# 2022-12-16          0.019431  0.030092 -0.010872  0.105837   0.055922
# 2022-12-23         -0.008722 -0.034636 -0.009522 -0.066703  -0.062163
# 2022-12-30          0.023825  0.052179  0.023781  0.022967   0.061850
# 2023-01-06          0.006125 -0.026201 -0.026227 -0.002816  -0.016613
#
#             short_corporate  Ted_spread
# Date
# 2000-12-29         0.498288   -0.970738
# 2001-01-05         0.083985   -1.535014
# 2001-01-12        -0.480135    4.552103
# 2001-01-19         0.688865   -3.392058
# 2001-01-26        -0.429689    1.350019
# ...                     ...         ...
# 2022-12-09        -0.049586   -0.168766
# 2022-12-16        -0.549819   -0.128033
# 2022-12-23         0.501080    0.349654
# 2022-12-30         0.073292   -0.417631
# 2023-01-06        -0.353854    0.464393
#
# [1150 rows x 13 columns]

# %%
index_data.to_excel('all_index_data1.xlsx')
